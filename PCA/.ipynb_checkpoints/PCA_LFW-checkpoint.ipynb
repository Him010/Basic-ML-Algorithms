# %%
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
lfw = datasets.fetch_lfw_people(min_faces_per_person = 100,resize = 0.4)

# %%
lfw.keys()
# Out:
# dict_keys(['data', 'images', 'target', 'target_names', 'DESCR'])

# %%
lfw.data.shape
# Out:
# (1140, 1850)

# %%
lfw.images.shape
# Out:
# (1140, 50, 37)

# %%
fig = plt.figure(figsize = (8,8))
for i in range(64):
    ax = fig.add_subplot(8,8,i+1)
    ax.imshow(lfw.images[i],cmap = plt.cm.bone)
    
plt.show()

# %%
x,y = lfw.data,lfw.target
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 42)
pca = PCA()
pca.fit(x_train)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
k = 0
total = sum(pca.explained_variance_)
curr = 0
while (curr/total)<0.995:
    curr += pca.explained_variance_[k]
    k +=1
    
k
# Out:
# 405

# %%
pca_lfw = PCA(n_components = k,whiten = True)
x_transformed = pca_lfw.fit_transform(x_train)
x_transformed.shape
# Out:
# (855, 405)

# %%
x_approx = pca_lfw.inverse_transform(x_transformed)
x_approx_images = x_approx.reshape((855,50,37))

# %%
fig = plt.figure(figsize = (8,8))
for i in range(64):
    ax = fig.add_subplot(8,8,i+1)
    ax.imshow(x_approx_images[i],cmap = plt.cm.bone)
    
plt.show()

# %%
eigenval = pca_lfw.components_
eigenface = eigenval.reshape((405,50,37))

# %%
fig = plt.figure(figsize = (8,8))
for i in range(64):
    ax = fig.add_subplot(8,8,i+1)
    ax.imshow(eigenface[i],cmap = plt.cm.bone)
    
plt.show()

# %%
x_train_pca = x_transformed
x_test_pca = pca_lfw.transform(x_test)

# %%
import time

# %%
rf = RandomForestClassifier()
start = time.time()
rf.fit(x_train,y_train)
print(time.time() - start)
y_pred = rf.predict(x_test)
print(classification_report(y_test,y_pred))
rf.score(x_test,y_test)
# Out:
# c:\users\himanshu\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.25520777702331543
#               precision    recall  f1-score   support
#
#            0       0.67      0.69      0.68        64
#            1       0.61      0.34      0.44        32
#            2       0.63      0.91      0.75       127
#            3       0.50      0.07      0.12        29
#            4       0.62      0.24      0.35        33
#
#     accuracy                           0.64       285
#    macro avg       0.60      0.45      0.47       285
# weighted avg       0.62      0.64      0.59       285
# 0.6350877192982456

# %%
rf = RandomForestClassifier()
start = time.time()
rf.fit(x_train_pca,y_train)
print(time.time() - start)
y_pred = rf.predict(x_test_pca)
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
rf.score(x_test_pca,y_test)
# Out:
# c:\users\himanshu\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.14059042930603027
#               precision    recall  f1-score   support
#
#            0       0.36      0.30      0.32        64
#            1       0.50      0.25      0.33        32
#            2       0.52      0.78      0.63       127
#            3       0.25      0.10      0.15        29
#            4       0.27      0.12      0.17        33
#
#     accuracy                           0.47       285
#    macro avg       0.38      0.31      0.32       285
# weighted avg       0.43      0.47      0.42       285
#
# [[19  1 40  2  2]
#  [ 4  8 17  0  3]
#  [17  2 99  4  5]
#  [ 7  4 14  3  1]
#  [ 6  1 19  3  4]]
# 0.4666666666666667

# %%
clf = SVC()
start = time.time()
clf.fit(x_train,y_train)
print(time.time() - start)
y_pred = clf.predict(x_test)
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
clf.score(x_test,y_test)
# Out:
# c:\users\himanshu\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 4.11365008354187
# c:\users\himanshu\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        64
#            1       0.00      0.00      0.00        32
#            2       0.45      1.00      0.62       127
#            3       0.00      0.00      0.00        29
#            4       0.00      0.00      0.00        33
#
#     accuracy                           0.45       285
#    macro avg       0.09      0.20      0.12       285
# weighted avg       0.20      0.45      0.27       285
#
# [[  0   0  64   0   0]
#  [  0   0  32   0   0]
#  [  0   0 127   0   0]
#  [  0   0  29   0   0]
#  [  0   0  33   0   0]]
# 0.4456140350877193

# %%
clf = SVC()
start = time.time()
clf.fit(x_train_pca,y_train)
print(time.time() - start)
y_pred = clf.predict(x_test_pca)
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
clf.score(x_test_pca,y_test)
# Out:
# c:\users\himanshu\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.8365921974182129
#               precision    recall  f1-score   support
#
#            0       1.00      0.48      0.65        64
#            1       0.00      0.00      0.00        32
#            2       0.51      1.00      0.67       127
#            3       1.00      0.03      0.07        29
#            4       1.00      0.09      0.17        33
#
#     accuracy                           0.57       285
#    macro avg       0.70      0.32      0.31       285
# weighted avg       0.67      0.57      0.47       285
#
# [[ 31   0  33   0   0]
#  [  0   0  32   0   0]
#  [  0   0 127   0   0]
#  [  0   0  28   1   0]
#  [  0   0  30   0   3]]
# c:\users\himanshu\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 0.5684210526315789

# %%
clf.score(x_test_pca,y_test)
# Out:
# 0.5684210526315789

# %%
from sklearn.model_selection import GridSearchCV

# %%
clf = SVC()
grid = {"C" : [10,1e2,1e3,1e4],
       "gamma" : [1e-1,1e-2,1e-3,1e-4]}
abc = GridSearchCV(clf,grid)
start = time.time()
abc.fit(x_train,y_train)
print(time.time() - start)
y_pred = abc.predict(x_test)
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
abc.score(x_test,y_test)
# Out:
# c:\users\himanshu\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# 107.55522227287292
# c:\users\himanshu\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        64
#            1       0.00      0.00      0.00        32
#            2       0.45      1.00      0.62       127
#            3       0.00      0.00      0.00        29
#            4       0.00      0.00      0.00        33
#
#     accuracy                           0.45       285
#    macro avg       0.09      0.20      0.12       285
# weighted avg       0.20      0.45      0.27       285
#
# [[  0   0  64   0   0]
#  [  0   0  32   0   0]
#  [  0   0 127   0   0]
#  [  0   0  29   0   0]
#  [  0   0  33   0   0]]
# 0.4456140350877193

# %%
abc.best_estimator_
# Out:
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.1, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
clf = SVC()
grid = {"C" : [10,1e2,1e3,1e4],
       "gamma" : [1e-1,1e-2,1e-3,1e-4]}
abc = GridSearchCV(clf,grid)
start = time.time()
abc.fit(x_train_pca,y_train)
print(time.time() - start)
y_pred = abc.predict(x_test_pca)
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
abc.score(x_test_pca,y_test)
# Out:
# c:\users\himanshu\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# 22.908079385757446
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85        64
#            1       0.88      0.72      0.79        32
#            2       0.84      0.90      0.87       127
#            3       1.00      0.72      0.84        29
#            4       0.88      0.70      0.78        33
#
#     accuracy                           0.85       285
#    macro avg       0.88      0.79      0.83       285
# weighted avg       0.85      0.85      0.84       285
#
# [[ 60   1   3   0   0]
#  [  4  23   4   0   1]
#  [ 10   1 114   0   2]
#  [  1   0   7  21   0]
#  [  2   1   7   0  23]]
# 0.8456140350877193

# %%
abc.best_estimator_
# Out:
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
abc.score(x_test_pca,y_test)
# Out:
# 0.8456140350877193
